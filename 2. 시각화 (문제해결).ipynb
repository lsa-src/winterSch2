# %% [markdown]
# **해결문제 01 ============================================================**
#
#
# > 지역평균기온.txt 파일을 읽어서 딕션너리를 만들고, 아래와 같이 그래프를 표시하시오.
#
# ![image01.png](data:image/png;base64,...)

# %% [markdown]
# ### 01. 그래프에서 한글표현을 하기 위한 글꼴 설치
# ---

# %%
#STEP 1. 나눔 폰트 설치 (Nanum)
# !sudo apt-get install -y fonts-nanum
# !sudo fc-cache -fv
# !rm ~/.cache/matplotlib -rf

# %%
#STEP 2. 코랩(Colab)의 런타임을 재시작

# %%
#STEP 3. matplotlib의 폰트를 Nanum 폰트로 지정
import matplotlib.pyplot as plt

plt.rc('font', family='NanumBarunGothic')

# %% [markdown]
# ### 02. 파일을 읽어들이기 위해 구글 드라이브 마운트 하기
# ---

# %%
#구글 드라이브 마운트 시키기

# %%
# 파일 읽어 들이기

# %% [markdown]
# ##03. 그래프를 그리기 위해 데이터 정제하기
# 1.   조건 대로 딕셔너리 만들기
# 2.   X, Y축 값 생성하기
# ---

# %%
# 딕셔너리 만들기
dt = {}

# %%
# 만들어진 딕셔너리에서 X축, Y 축 값을 추출하여, 각각을 area, temp list로 정리하기

# %%
# 그래프 그리기

# %%
# 해당지역의 평균기온을 알려주는 프로그램을 추가하시오.
#– 단, 지역입력에 q가 입력되면, 종료
# Out:
# 지역을 입력하세요 (q:종료) q
